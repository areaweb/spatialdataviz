# %% [markdown]
# ## https://www.setlist.fm/search?query=scorpions

# %%
from robobrowser import RoboBrowser
import geocoder
import folium
import pandas as pd
import dateparser
from joblib import Memory
import difflib
import pycountry
from iso3166 import countries
memory = Memory(cachedir='tmp', verbose=0)

# %%
url = 'https://www.setlist.fm/search?query=scorpions'
browser = RoboBrowser(history=True, parser='html5lib')
browser.open(url)
concert = browser.select('.setlistPreview')[0]
concert
# Out:
# <div class="col-xs-12 setlistPreview">
# <div>
# <div class="condensed dateBlock">
# <span class="month">Nov</span>
# <span class="day">1</span>
# <span class="year">2017</span>
#
# </div>
# </div>
# <div>
# <h2><a href="setlist/scorpions/2017/olympijskiy-stadium-moscow-russia-23e36c7b.html" title="View this Scorpions setlist">Scorpions at Olympijskiy Stadium, Moscow, Russia</a></h2>
# <div class="details">
# <span>Artist: <strong><a href="setlists/scorpions-3d63ddf.html" title="More Scorpions setlists"><span>Scorpions</span></a></strong></span>,
#
# <span>
# Tour:
# <strong><a href="search?artist=3d63ddf&amp;query=tour:%28Crazy+World+2017+Tour%29" rel="nofollow" title='Search Scorpions setlists by tour: "Crazy World 2017 Tour"'>Crazy World 2017 Tour</a></strong>
# </span>,
#
# <span>Venue: <strong><a href="venue/olympijskiy-stadium-moscow-russia-13d63975.html" title="More setlists from Olympijskiy Stadium, Moscow, Russia"><span>Olympijskiy Stadium, Moscow, Russia</span></a></strong></span>
# </div>
# <div class="setSummary">
#
# </div>
# <div class="actions">
# <div class="editSetlistLink btn-group text-left hidden-print">
# <a class="btn btn-link btnEdit nested" href="edit?setlist=23e36c7b&amp;step=song" title="Edit setlist" type="button">
# <i class="fa fa-pencil fa-fw"></i> <span>Edit setlist songs</span>
# </a>
# <a aria-expanded="false" aria-haspopup="true" class="btn btn-link btnEdit dropdown-toggle btnToggle" data-toggle="dropdown" type="button">
# <span><i class="fa fa-chevron-down fa-adapt-height"></i></span>
# <span class="sr-only">Show all edit options</span>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a class="editLink" href="edit?setlist=23e36c7b&amp;step=song" rel="nofollow" title="Edit setlist">
# <span>Edit setlist songs</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="edit?setlist=23e36c7b&amp;step=artist" rel="nofollow" title="Edit setlist">
# <span>Edit venue &amp; date</span>
# </a>
# </li>
# <li>
# <a class="editLink" href="edit?setlist=23e36c7b&amp;step=tour" rel="nofollow" title="Edit setlist">
# <span>Edit tour &amp; festival</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>

# %%
day = concert.select('.day')[0].text
month = concert.select('.month')[0].text
year = concert.select('.year')[0].text
desc = concert.select('h2 a')[0].text
print(day,month,year,desc)
# Out:
# 1 Nov 2017 Scorpions at Olympijskiy Stadium, Moscow, Russia

# %%
idx = desc.find(' at ')+4
loc = desc[idx:]
loc_pieces = loc.split(',')
if len(loc_pieces)>=3:
    loc = ','.join(loc_pieces[-3:])
print(loc)
# Out:
# Olympijskiy Stadium, Moscow, Russia

# %%
g=geocoder.google(loc)
print(g.geojson)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'accuracy': 'ROOFTOP', 'address': 'Olimpiyskiy pr., 16с1, Moskva, Russia, 129090', 'bbox': [37.6251080197085, 55.7797010197085, 37.6278059802915, 55.7823989802915], 'city': 'Moskva', 'confidence': 9, 'country': 'RU', 'county': 'Moskva', 'housenumber': '16с1', 'lat': 55.78105, 'lng': 37.62645699999999, 'ok': True, 'place': 'ChIJQcqpSw1KtUYRrBjnAynHt5E', 'postal': '129090', 'quality': 'establishment', 'raw': {'address_components': [{'long_name': '16 строение 1', 'short_name': '16с1', 'types': ['street_number']}, {'long_name': 'Olimpiyskiy prospekt', 'short_name': 'Olimpiyskiy pr.', 'types': ['route']}, {'long_name': 'Tsentralnyy administrativnyy okrug', 'short_name': 'Tsentralnyy administrativnyy okrug', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Moskva', 'short_name': 'Moskva', 'types': ['locality', 'political']}, {'long_name': 'Moskva', 'short_name': 'Moskva', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Russia', 'short_name': 'RU', 'types': ['country', 'political']}, {'long_name': '129090', 'short_name': '129090', 'types': ['postal_code']}], 'formatted_address': 'Olimpiyskiy pr., 16с1, Moskva, Russia, 129090', 'geometry': {'location': {'lat': 55.78105, 'lng': 37.62645699999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 55.7823989802915, 'lng': 37.6278059802915}, 'southwest': {'lat': 55.7797010197085, 'lng': 37.6251080197085}}}, 'partial_match': True, 'place_id': 'ChIJQcqpSw1KtUYRrBjnAynHt5E', 'types': ['establishment', 'point_of_interest'], 'location': {'lat': 55.78105, 'lng': 37.62645699999999}, 'location_type': 'ROOFTOP', 'bounds': {}, 'northeast': {'lat': 55.7823989802915, 'lng': 37.6278059802915}, 'southwest': {'lat': 55.7797010197085, 'lng': 37.6251080197085}, 'street_number': {'long_name': '16 строение 1', 'short_name': '16с1'}, 'route': {'long_name': 'Olimpiyskiy prospekt', 'short_name': 'Olimpiyskiy pr.'}, 'political': {'long_name': 'Russia', 'short_name': 'RU'}, 'sublocality': {'long_name': 'Tsentralnyy administrativnyy okrug', 'short_name': 'Tsentralnyy administrativnyy okrug'}, 'sublocality_level_1': {'long_name': 'Tsentralnyy administrativnyy okrug', 'short_name': 'Tsentralnyy administrativnyy okrug'}, 'locality': {'long_name': 'Moskva', 'short_name': 'Moskva'}, 'administrative_area_level_2': {'long_name': 'Moskva', 'short_name': 'Moskva'}, 'country': {'long_name': 'Russia', 'short_name': 'RU'}, 'postal_code': {'long_name': '129090', 'short_name': '129090'}}, 'status': 'OK', 'street': 'Olimpiyskiy pr.', 'sublocality': 'Tsentralnyy administrativnyy okrug'}, 'bbox': [37.6251080197085, 55.7797010197085, 37.6278059802915, 55.7823989802915], 'geometry': {'type': 'Point', 'coordinates': [37.62645699999999, 55.78105]}}]}

# %%
code=g.geojson['features'][0]['properties']['country']
print(code)
# Out:
# RU

# %%
from iso3166 import countries
code=countries.get(code).alpha3
print(code)
# Out:
# RUS

# %%
@memory.cache
def get_latlng(query):
    try:
        g=geocoder.google(query)
        if g:
            country = g.geojson['features'][0]['properties']['country']
            code=countries.get(country).alpha3
            print(query, g.latlng, code)
            return g.latlng+[code]
        else:
            return None, None, None
    except:
        return None, None, None
    

@memory.cache
def get_data_paged(query, page):
    url = 'https://www.setlist.fm/search?page={}&query={}'.format(page, query)
    browser.open(url.format(page))
    data = []
    for concert in browser.select('.setlistPreview'):
        month = concert.select('.month')[0].text
        day = concert.select('.day')[0].text
        year = concert.select('.year')[0].text
        datetext = "{}, {} {}".format(year, month, day)
        date = dateparser.parse(datetext)
        desc = concert.select('h2 a')[0].text
        idx = desc.find(' at ')+4
        loc = desc[idx:]
        loc_pieces = loc.split(',')
        #print(loc_pieces[-1],country)
        if loc == None:
            continue
        if len(loc_pieces)>=3:
            loc = ','.join(loc_pieces[-3:])
        lat, lng, code = get_latlng(loc)
        if lat and lng:
            data.append([loc, lat, lng, code, date, desc])
    return data
    
columns = ['loc', 'lat', 'lon', 'code', 'date', 'desc']
concerts = pd.DataFrame(columns = columns)
for page in range(1,15):
    data = get_data_paged('Scorpions', page)
    df = pd.DataFrame(data, columns = columns)
    concerts = concerts.append(df)

concerts.head(20)
# Out:
#                                                  loc        lat         lon  \
# 0                Olympijskiy Stadium, Moscow, Russia  55.781050   37.626457
# 1                SK "Basket Hall", Krasnodar, Russia  45.117544   38.981297
# 2             Ledovaya Arena 'Shayba', Sochi, Russia  43.402260   39.951905
# 3                                 Inglewood, CA, USA  33.961680 -118.353131
# 4                                   Oakland, CA, USA  37.804364 -122.271114
# 5                                      Reno, NV, USA  39.529633 -119.813803
# 6                                    Tacoma, WA, USA  47.252877 -122.444291
# 7                                   Spokane, WA, USA  47.658780 -117.426046
# 8                               West Valley, UT, USA  40.691613 -112.001050
# 0                                  Rosemont, IL, USA  41.986751  -87.872160
# 1                                Toronto, ON, Canada  43.653226  -79.383184
# 2                                  Laval, QC, Canada  45.606649  -73.712409
# 3                                  New York, NY, USA  40.712775  -74.005973
# 4                                   Reading, PA, USA  40.335648  -75.926875
# 5                         Münsterplatz, Ulm, Germany  48.399008    9.991753
# 6                     Guitare en scène Festival 2017  46.139233    6.071985
# 7                             Festival de Nîmes 2017  43.834904    4.359615
# 8                          Festival Marés Vivas 2017  41.139685   -8.653662
# 9  Albergue Municipal Juvenil El Prado, Mérida, S...  38.930452   -6.401968
# 0             Campos del Malecón, Torrelavega, Spain  43.350213   -4.062679
#
#   code       date                                               desc
# 0  RUS 2017-11-01   Scorpions at Olympijskiy Stadium, Moscow, Russia
# 1  RUS 2017-10-30   Scorpions at SK "Basket Hall", Krasnodar, Russia
# 2  RUS 2017-10-28  Scorpions at Ledovaya Arena 'Shayba', Sochi, R...
# 3  USA 2017-10-07         Scorpions at The Forum, Inglewood, CA, USA
# 4  USA 2017-10-04        Scorpions at Oracle Arena, Oakland, CA, USA
# 5  USA 2017-10-03   Scorpions at Grand Sierra Theatre, Reno, NV, USA
# 6  USA 2017-09-30          Scorpions at Tacoma Dome, Tacoma, WA, USA
# 7  USA 2017-09-29       Scorpions at Spokane Arena, Spokane, WA, USA
# 8  USA 2017-09-26  Scorpions at USANA Amphitheatre, West Valley, ...
# 0  USA 2017-09-23     Scorpions at Allstate Arena, Rosemont, IL, USA
# 1  CAN 2017-09-22  Scorpions at Budweiser Stage, Toronto, ON, Canada
# 2  CAN 2017-09-19         Scorpions at Place Bell, Laval, QC, Canada
# 3  USA 2017-09-16  Scorpions at Madison Square Garden, New York, ...
# 4  USA 2017-09-14     Scorpions at Santander Arena, Reading, PA, USA
# 5  DEU 2017-07-23            Scorpions at Münsterplatz, Ulm, Germany
# 6  FRA 2017-07-19        Scorpions at Guitare en scène Festival 2017
# 7  FRA 2017-07-17                Scorpions at Festival de Nîmes 2017
# 8  PRT 2017-07-15             Scorpions at Festival Marés Vivas 2017
# 9  ESP 2017-07-14  Scorpions at Albergue Municipal Juvenil El Pra...
# 0  ESP 2017-07-12  Scorpions at Campos del Malecón, Torrelavega, ...

# %%
import plotly.plotly as py

great_lines = [ 
        dict(
            type = 'scattergeo',
            lon = concerts['lon'],
            lat = concerts['lat'],
            mode = 'lines',
            line = dict(
                    width = 1,
                    color = 'rgba(255,0,0,0.5)',
                    ),
        )
        ]
venue_markers = [ dict(
        type = 'scattergeo',
        lon = concerts['lon'],
        lat = concerts['lat'],
        hoverinfo = 'loc',
        text = concerts['loc'],
        mode = 'markers',
        marker = dict( 
            size=10, 
            color='rgba(255,0,0,0.5)',   
        ))]
    
layout = dict(
        title = 'recitales',
        width = 1000,
        height = 800,
            showlegend = False, 

            showland = True,
            showcountries = True,
            showocean = True,
            countrywidth = 0.5,
            landcolor = '#fff',
            oceancolor = '#eee',
    
        geo = dict(
            projection = dict( 
                type = 'Mercator',          
            ),
            
        )
    )
    
fig = dict( data=great_lines+venue_markers, layout=layout )
py.iplot( fig, validate=False, filename='d3-globe' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~culagovski/4.embed" height="800px" width="1000px"></iframe>

# %%
df = concerts.groupby('code').count()
df.head(20)

# %%
df=df.reset_index()
df.head(20)

# %%
data = [ dict(
        type = 'choropleth',
        locations = df['code'],
        z = df['loc'],
        autocolorscale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            tickprefix = '',
            title = 'concerts'),
      ) ]

markers = [ dict(
        type = 'scattergeo',
        lon = concerts['lon'],
        lat = concerts['lat'],
        hovertext  = concerts['loc'],
        text = concerts['loc'] ,
        textposition = 'top center',
        mode = 'markers',
        string = concerts['loc'],
        marker = dict( 
            symbol = ['4'],
            size=10, 
            color='black',  
            linecolor = 'white'
            
        ))]

layout = dict(
    width = 800,
    height = 800,
    showlegend = False, 
    title = 'concerts scorpions',
    geo = dict(
        showframe = True,
        showcoastlines = True,
        projection = dict( 
                type = 'orthographic',
                rotation = dict(
                    lon = -100,
                    lat = 40,
                    roll = 0
                )            
            ),
    )
)

fig = dict( data=data+markers+great_lines, layout=layout )
py.iplot( fig, validate=False, filename='d3-world-map' )
