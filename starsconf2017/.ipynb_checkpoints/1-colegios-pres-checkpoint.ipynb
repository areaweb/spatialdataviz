# %% [markdown]
# # [Puntajes PSU](http://www.t13.cl/noticia/nacional/te-puede-servir/ranking-colegios-mejor-promedio-psu-2016)

# %%
from robobrowser import RoboBrowser
import geocoder
import folium
import pandas
import os
from utils import persist_to_file
cwd = os.getcwd()

browser = RoboBrowser(history=True, parser='html5lib')
url = 'http://www.t13.cl/noticia/nacional/te-puede-servir/ranking-colegios-mejor-promedio-psu-2016'
browser.open(url)

# %%
table=browser.select('.article-content table')[0]
t=table.__str__()
t[:1000]
# Out:
# '<table border="0" cellpadding="0" cellspacing="0" style="width:1059px;" width="1058">\n\t<colgroup>\n\t\t<col/>\n\t\t<col/>\n\t\t<col/>\n\t\t<col/>\n\t\t<col/>\n\t\t<col/>\n\t</colgroup>\n\t<tbody>\n\t\t<tr height="20">\n\t\t\t<td height="20" style="height: 20px; width: 143px; text-align: center;"><strong>Posición en el ranking</strong></td>\n\t\t\t<td style="width: 159px; text-align: center;"><strong>Tipo de establecimiento</strong></td>\n\t\t\t<td style="width: 131px; text-align: center;"><strong>Comuna\xa0</strong></td>\n\t\t\t<td style="width: 332px; text-align: center;"><strong>Colegio</strong></td>\n\t\t\t<td style="width: 215px; text-align: center;"><strong>Alumnos que rindieron la prueba</strong></td>\n\t\t\t<td style="width: 80px; text-align: center;"><strong>Promedio PSU</strong></td>\n\t\t</tr>\n\t\t<tr height="20">\n\t\t\t<td height="20" style="height: 20px; text-align: center;">1</td>\n\t\t\t<td style="text-align: center;">Particular</td>\n\t\t\t<td style="text-align: center;">Providencia\xa0</td>\n\t\t\t<td style="text-align: center;">Cambridge Coll'

# %%
t=t.replace(',','.')
df=pandas.read_html(t, header=0)[0]
df.head(10)
# Out:
#    Posición en el ranking Tipo de establecimiento        Comuna  \
# 0                       1              Particular   Providencia
# 1                       2              Particular    Las Condes
# 2                       3              Particular        Concón
# 3                       4              Particular         Maipú
# 4                       5              Particular      Vitacura
# 5                       6              Particular  Puerto Montt
# 6                       7              Particular  Lo Barnechea
# 7                       8              Particular   Chiguayante
# 8                       9              Particular         Angol
# 9                      10              Particular      La Reina
#
#               Colegio  Alumnos que rindieron la prueba  Promedio PSU
# 0   Cambridge College                               29         704.4
# 1          Cordillera                               63         699.0
# 2            Montemar                               22         694.0
# 3  Internacional Alba                               26         693.4
# 4           Los Andes                               69         692.9
# 5    Instituto Alemán                               46         690.9
# 6   Maimonides School                               10         689.7
# 7             Pinares                               16         685.5
# 8            San José                               19         683.7
# 9   The Grange School                              133         682.6

# %%
g=geocoder.google('colegio the grange school, la reina, chile')
print(g)
print(g.latlng)
# Out:
# <[OK] Google - Geocode #2 results>
# [-33.438182, -70.5685989]

# %%
g.latlng
# Out:
# [-33.438182, -70.5685989]

# %% [markdown]
# [-36.8883627, -73.0351594](
# https://www.google.cl/maps/@-33.4382165,-70.5686165,3a,75y,3.98h,101.74t/data=!3m7!1e1!3m5!1sxP13kKF1tvm6pau-DNnsPA!2e0!6s%2F%2Fgeo1.ggpht.com%2Fcbk%3Fpanoid%3DxP13kKF1tvm6pau-DNnsPA%26output%3Dthumbnail%26cb_client%3Dmaps_sv.tactile.gps%26thumb%3D2%26w%3D203%26h%3D100%26yaw%3D33.012394%26pitch%3D0%26thumbfov%3D100!7i13312!8i6656)

# %%
import time
import json

@persist_to_file()
def get_latlng(query):
    providers = geocoder.osm, geocoder.google
    for provider in providers:
        #print(provider)
        try:  
            g=provider(query)
        except ValueError:
            continue
        if g:
            return g.latlng
    return None, None

def get_latlng_nocache(query):
    providers = geocoder.osm, geocoder.google
    for provider in providers:
        #print(provider)
        try:  
            g=provider(query)
        except ValueError:
            continue
        if g:
            return g.latlng
    return None, None

for index,row in df.iterrows():
    stopwords = 'colegio', 'liceo', 'school', 'instituto', 'college'
    query = row.Colegio +", "+ row.Comuna + ", chile"
    query = query.lower()
    for i in stopwords:
        if i in query:
            break
    else:
         query = 'colegio ' + query
    print(query),
    g=get_latlng(query)
    time.sleep(0.1)
    if not g:
        print('ERROR', query)
        continue
    if g:
        lat, lng = g
        df.set_value(index,'lat', lat)
        df.set_value(index,'lng', lng)
        print(g)
    else:
        print(g, 'ERROR', query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-245725365427> in <module>()
#       2 import json
#       3
# ----> 4 @persist_to_file()
#       5 def get_latlng(query):
#       6     providers = geocoder.osm, geocoder.google
#
# TypeError: persist_to_file() missing 1 required positional argument: 'file_name'

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Posición en el ranking Tipo de establecimiento               Comuna  \
# 8                        9              Particular                Angol
# 48                      49              Particular  San Pedro de la Paz
# 76                      77              Particular            La Serena
# 78                      79              Particular            Rancuagua
# 81                      82              Particular             La Reina
# 96                      97           Subvencionado              Copiapó
# 98                      99               Municipal             La Unión
#
#                               Colegio  Alumnos que rindieron la prueba  \
# 8                            San José                               19
# 48               Alemán de Concepción                               68
# 76  Scuola Italiana Alcide De Gasperi                               45
# 78          Instituto Inglés Rancagua                               76
# 81       Colegio British Royal School                               63
# 96  Colegio San Francisco de la Selva                               15
# 98                  Escuela El Maitén                                1
#
#     Promedio PSU  lat  lng
# 8          683.7  NaN  NaN
# 48         658.4  NaN  NaN
# 76         649.7  NaN  NaN
# 78         649.2  NaN  NaN
# 81         648.0  NaN  NaN
# 96         643.2  NaN  NaN
# 98         643.0  NaN  NaN

# %%
df=df.dropna()
df.head(25)
# Out:
#     Posición en el ranking Tipo de establecimiento        Comuna  \
# 0                        1              Particular   Providencia
# 1                        2              Particular    Las Condes
# 2                        3              Particular        Concón
# 3                        4              Particular         Maipú
# 4                        5              Particular      Vitacura
# 5                        6              Particular  Puerto Montt
# 6                        7              Particular  Lo Barnechea
# 7                        8              Particular   Chiguayante
# 9                       10              Particular      La Reina
# 10                      11              Particular  Lo Barnechea
# 11                      12              Particular     Talagante
# 12                      13              Particular      Vitacura
# 13                      14              Particular   Providencia
# 14                      15              Particular    Las Condes
# 15                      16              Particular        Arauco
# 16                      17              Particular  Lo Barnechea
# 17                      18              Particular  Lo Barnechea
# 18                      19              Particular         Ñuñoa
# 19                      20           Subvencionado   Providencia
# 20                      21              Particular      La Reina
# 21                      22              Particular  Puerto Varas
# 23                      24              Particular  Viña del Mar
# 24                      25              Particular  Lo Barnechea
# 25                      26              Particular   Chiguayante
# 26                      27              Particular    Las Condes
#
#                         Colegio  Alumnos que rindieron la prueba  \
# 0             Cambridge College                               29
# 1                    Cordillera                               63
# 2                      Montemar                               22
# 3            Internacional Alba                               26
# 4                     Los Andes                               69
# 5              Instituto Alemán                               46
# 6             Maimonides School                               10
# 7                       Pinares                               16
# 9             The Grange School                              133
# 10             Instituto Hebreo                               76
# 11                     Trebulco                               22
# 12                    Tabancura                              107
# 13              The Kent School                               61
# 14                 La Girouette                               55
# 15                       Arauco                               21
# 16                  Los Alerces                               61
# 17           The Newland School                               82
# 18             Francisco Encina                               24
# 19  Josefino Santísima Trinidad                               27
# 20        Andreé English School                              138
# 21                 Puerto Varas                               46
# 23                      Albamar                               31
# 24              Nido de Águilas                               27
# 25                       Itahue                                7
# 26                      Cumbres                              202
#
#     Promedio PSU        lat        lng
# 0          704.4 -33.429730 -70.617110
# 1          699.0 -33.397130 -70.514321
# 2          694.0 -32.951048 -71.535463
# 3          693.4 -33.480574 -70.744990
# 4          692.9 -33.375795 -70.527009
# 5          690.9 -41.470315 -72.932780
# 6          689.7 -33.362362 -70.485016
# 7          685.5 -36.932918 -73.024080
# 9          682.6 -33.436938 -70.567836
# 10         681.0 -33.367826 -70.508976
# 11         680.8 -33.684922 -70.918144
# 12         679.4 -33.380335 -70.534838
# 13         678.5 -33.442454 -70.606202
# 14         678.2 -33.420144 -70.568444
# 15         676.0 -37.248822 -73.306187
# 16         675.6 -33.364459 -70.518310
# 17         675.6 -33.359939 -70.532781
# 18         675.6 -33.463760 -70.600446
# 19         673.5 -33.435876 -70.618879
# 20         672.6 -33.439611 -70.551921
# 21         671.8 -41.308480 -72.993136
# 23         669.7 -32.960457 -71.540695
# 24         669.7 -33.351119 -70.503166
# 25         669.6 -36.888363 -73.035159
# 26         668.8 -33.393348 -70.502106

# %%
map = folium.Map(location=[-33.39, -70.57], zoom_start=8, tiles='Stamen Terrain')
i=0
for index, row in df.iterrows():
    map.add_child(
        folium.CircleMarker([row.lat,row.lng],
                            color='#000000',
                            fill_color='#ff0000',
                            fill=True,
                            fill_opacity=0.7,
                            radius=5, 
                            popup=u"%s %s %s" % (row.Colegio, row['Promedio PSU'], row['Comuna'])))
map.save('colegios.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.head()
# Out:
#    Posición en el ranking Tipo de establecimiento       Comuna  \
# 0                       1              Particular  Providencia
# 1                       2              Particular   Las Condes
# 2                       3              Particular       Concón
# 3                       4              Particular        Maipú
# 4                       5              Particular     Vitacura
#
#               Colegio  Alumnos que rindieron la prueba  Promedio PSU  \
# 0   Cambridge College                               29         704.4
# 1          Cordillera                               63         699.0
# 2            Montemar                               22         694.0
# 3  Internacional Alba                               26         693.4
# 4           Los Andes                               69         692.9
#
#          lat        lng
# 0 -33.429787 -70.616853
# 1 -33.396461 -70.513284
# 2 -32.950793 -71.535073
# 3 -33.480762 -70.745021
# 4 -33.375544 -70.526525

# %%
map = folium.Map(location=[-33.39, -70.57], zoom_start=8, tiles='Stamen Toner')
i=0
for index, row in df.iterrows():
    map.add_child(
        folium.CircleMarker([row.lat,row.lng],
                            color='#ff0000',
                            fill_color='#ff0000',
                            fill=True,
                            fill_opacity=0.7,
                            radius=5*row['Alumnos que rindieron la prueba']/100.0, 
                            popup=u"%s %s %s %s alumnos" % (row.Colegio, row['Promedio PSU'], row['Comuna'], row['Alumnos que rindieron la prueba'])))
map.save('colegios.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.tail(20)
# Out:
#     Posición en el ranking Tipo de establecimiento        Comuna  \
# 74                      75              Particular         Ñuñoa
# 75                      76              Particular     Peñalolén
# 77                      78              Particular     Peñalolén
# 79                      80              Particular    Las Condes
# 80                      81              Particular  Viña del Mar
# 82                      83           Subvencionado      Vitacura
# 83                      84              Particular  Lo Barnechea
# 84                      85              Particular         Talca
# 85                      86              Particular  Constitución
# 86                      87           Subvencionado     La Serena
# 87                      88              Particular         Ñuñoa
# 88                      89              Particular   Antofagasta
# 89                      90              Particular    Las Condes
# 90                      91              Particular        Temuco
# 91                      92              Particular    Las Condes
# 92                      93              Particular      Rancagua
# 94                      95              Particular        Concón
# 95                      96              Particular          Buin
# 97                      98              Particular        Colina
# 99                     100              Particular   Calle Larga
#
#                                        Colegio  \
# 74                   Colegio Suizo de Santiago
# 75                             Colegio Pumahue
# 77       Colegio Pedro de Valdivia - Peñalolén
# 79                      Colegio Wenlock School
# 80                Colegio Alemán de Valparaíso
# 82                    Liceo María Luisa Bombal
# 83                          Colegio Craighouse
# 84                              Colegio Inglés
# 85                        Colegio Constitución
# 86                     Colegio Gerónimo Rendic
# 87                Colegio Saint Gaspar College
# 88  Colegio Internacional Antofagasta Limitada
# 89                   Colegio Francisco de Asis
# 90                          Green House School
# 91        Colegio Pedro de Valdivia Las Condes
# 92                   Colegio Inglés Saint John
# 94       Colegio Británico St. Margaret´s S.A.
# 95                          Colegio Campanario
# 97             Colegio Dunalastair Valle Norte
# 99                          Sun Valley College
#
#     Alumnos que rindieron la prueba  Promedio PSU        lat        lng
# 74                               32         650.6 -33.456659 -70.608401
# 75                               88         650.1 -33.497000 -70.546760
# 77                              157         649.6 -33.493105 -70.576597
# 79                               49         649.0 -33.410778 -70.522065
# 80                               65         648.3 -33.039007 -71.526086
# 82                               35         648.0 -33.388298 -70.579639
# 83                              106         647.7 -33.363000 -70.510160
# 84                               54         647.6 -35.450989 -71.596914
# 85                               13         647.6 -35.329400 -72.413134
# 86                              112         647.5 -29.904190 -71.243704
# 87                               52         647.3 -33.459967 -70.605051
# 88                               25         646.8 -23.728248 -70.436844
# 89                               94         645.8 -33.391951 -70.509459
# 90                               61         645.8 -38.741164 -72.637781
# 91                               57         644.9 -33.370714 -70.508043
# 92                               57         644.0 -34.175405 -70.723104
# 94                               55         643.3 -32.939660 -71.530507
# 95                               40         643.2 -33.738532 -70.692462
# 97                               25         643.2 -33.306561 -70.666478
# 99                               12         642.5 -32.860010 -70.589402

# %%
df3 = df[df['Tipo de establecimiento'] != 'Particular']
df3
# Out:
#     Posición en el ranking Tipo de establecimiento       Comuna  \
# 19                      20           Subvencionado  Providencia
# 33                      34               Municipal        Ñuñoa
# 64                      65           Subvencionado  San Vicente
# 82                      83           Subvencionado     Vitacura
# 86                      87           Subvencionado    La Serena
#
#                         Colegio  Alumnos que rindieron la prueba  \
# 19  Josefino Santísima Trinidad                               27
# 33       Liceo Augusto D´Halmar                               60
# 64          Colegio El Salvador                               65
# 82     Liceo María Luisa Bombal                               35
# 86      Colegio Gerónimo Rendic                              112
#
#     Promedio PSU        lat        lng
# 19         673.5 -33.435876 -70.618879
# 33         665.0 -33.460163 -70.581265
# 64         652.5 -34.439299 -71.084709
# 82         648.0 -33.388298 -70.579639
# 86         647.5 -29.904190 -71.243704

# %%
map = folium.Map(location=[-33.39, -70.57], zoom_start=8, tiles='OpenStreetMap')
colors = {
    'Particular': ('green', ''),
    'Subvencionado': ('red', 'star'),
    'Municipal': ('red', 'star-empty'),
}
for index, row in df.iterrows():
    color, icon = colors[row['Tipo de establecimiento']]
    folium.Marker(
        location=[row.lat,row.lng],
        popup=u"%s - %s - %s - %s" % (row['Tipo de establecimiento'], row.Colegio, row['Promedio PSU'], row['Comuna']),
        icon=folium.Icon(color=color, icon=icon)
    ).add_to(map)
map.save('colegios.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# [mapa](colegios.html)
