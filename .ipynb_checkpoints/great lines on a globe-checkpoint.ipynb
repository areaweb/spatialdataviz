# %%
import plotly.plotly as py
import pandas as pd

great_lines = [ dict(
    type = 'scattergeo',
    lat = [ 40.7127, 51.5072 ],
    lon = [ -74.0059, 0.1275 ],
    mode = 'lines',
    line = dict(
        width = 4,
        color = 'red',
    ),
),
             dict(
    type = 'scattergeo',
    lat = [ 45.7127, 55.5072 ],
    lon = [ -70.0059, 5.1275 ],
    mode = 'lines',
    line = dict(
        width = 4,
        color = 'red',
    ),
)]
    
layout = dict(
        title = 'Great lines over globe<br>(Click and drag to rotate)',
        showlegend = False,         
        geo = dict(
            showland = True,
            showlakes = True,
            showcountries = True,
            showocean = True,
            countrywidth = 0.5,
            landcolor = '#999',
            lakecolor = '#acf',
            oceancolor = '#acf',
            projection = dict( 
                type = 'orthographic',
                rotation = dict(
                    lon = -100,
                    lat = 40,
                    roll = 0
                )            
            ),
            lonaxis = dict( 
                showgrid = True,
                gridcolor = 'rgb(102, 102, 102)',
                gridwidth = 0.5
            ),
            lataxis = dict( 
                showgrid = True,
                gridcolor = 'rgb(102, 102, 102)',
                gridwidth = 0.5
            )
        )
    )
    
fig = dict( data=great_lines, layout=layout )
py.iplot( fig, validate=False, filename='d3-globe' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~culagovski/4.embed" height="525px" width="100%"></iframe>

# %%
from robobrowser import RoboBrowser
import plotly.plotly as py
import pandas as pd

browser = RoboBrowser(history=True, parser='html5lib')
base_url = 'https://flightaware.com/live/fleet/'
query = 'CCA' ## LAN KLM JAL BAW AAL CGW CCA
df = pd.DataFrame()
for i in range(10):
    url = base_url + query + "?;offset=" + str(i*20)
    browser.open(url)
    table=browser.select('.prettyTable')[0]
    t=table.__str__()
    if 'Sorry' in t:
            break
    tdf=pd.read_html(t, header=1)[0]
    df = df.append(tdf)
print(i)
df
# Out:
# 9
#       Ident  Type                                 Origin  \
# 0    CCA101  A321     Beijing Capital Int'l (PEK / ZBAA)
# 1    CCA103  B738      Tianjin Binhai Int'l (TSN / ZBTJ)
# 2   CCA1114  B738                     Wuhai (WUA / ZBUH)
# 3   CCA1117  A321     Beijing Capital Int'l (PEK / ZBAA)
# 4   CCA1132  B738           Hailar Dongshan (HLD / ZBLA)
# 5    CCA118  B738           Hong Kong Int'l (HKG / VHHH)
# 6   CCA1206  A320      Xi'an Xianyang Int'l (XIY / ZLXY)
# 7   CCA1213  A320     Beijing Capital Int'l (PEK / ZBAA)
# 8   CCA1216  A321     Shanghai Pudong Int'l (PVG / ZSPD)
# 9   CCA1228   73K        Yinchuan Helanshan (INC / ZLIC)
# 10   CCA123  B738     Beijing Capital Int'l (PEK / ZBAA)
# 11  CCA1245  B738      Tianjin Binhai Int'l (TSN / ZBTJ)
# 12  CCA1255  B738     Beijing Capital Int'l (PEK / ZBAA)
# 13  CCA1258  A320     Shanghai Pudong Int'l (PVG / ZSPD)
# 14  CCA1269  B738     Beijing Capital Int'l (PEK / ZBAA)
# 15  CCA1273  A320     Beijing Capital Int'l (PEK / ZBAA)
# 16  CCA1287  B738     Beijing Capital Int'l (PEK / ZBAA)
# 17  CCA1289  A321     Beijing Capital Int'l (PEK / ZBAA)
# 18   CCA129  B738     Beijing Capital Int'l (PEK / ZBAA)
# 19  CCA1293  B738     Beijing Capital Int'l (PEK / ZBAA)
# 0   CCA1299  B738     Beijing Capital Int'l (PEK / ZBAA)
# 1   CCA1306  B738     Shenzhen Bao'an Int'l (SZX / ZGSZ)
# 2   CCA1310  B77W    Guangzhou Baiyun Int'l (CAN / ZGGG)
# 3   CCA1317  B738      Tianjin Binhai Int'l (TSN / ZBTJ)
# 4   CCA1321  B773     Beijing Capital Int'l (PEK / ZBAA)
# 5   CCA1332  B738  Zhengzhou Xinzheng Int'l (CGO / ZHCC)
# 6   CCA1335  B732     Beijing Capital Int'l (PEK / ZBAA)
# 7   CCA1338  A330     Shenzhen Bao'an Int'l (SZX / ZGSZ)
# 8   CCA1343  B738     Beijing Capital Int'l (PEK / ZBAA)
# 9   CCA1351  A320     Beijing Capital Int'l (PEK / ZBAA)
# ..      ...   ...                                    ...
# 10   CCA781  A330     Beijing Capital Int'l (PEK / ZBAA)
# 11   CCA783  B789     Beijing Capital Int'l (PEK / ZBAA)
# 12   CCA818  B77W          Washington Dulles Intl (KIAD)
# 13   CCA820  B77W             Newark Liberty Intl (KEWR)
# 14  CCA8201  A320              Wuhan Tianhe (WUH / ZHHH)
# 15  CCA8223  A320              Wuhan Tianhe (WUH / ZHHH)
# 16  CCA8233  A320              Wuhan Tianhe (WUH / ZHHH)
# 17  CCA8240  A320                    Linfen Qiaoli (LFQ)
# 18  CCA8247  A320              Wuhan Tianhe (WUH / ZHHH)
# 19   CCA827  A332     Shanghai Pudong Int'l (PVG / ZSPD)
# 0   CCA8293  B738      Tianjin Binhai Int'l (TSN / ZBTJ)
# 1    CCA830  A332                  San Jose Int'l (KSJC)
# 2    CCA833  A330     Shanghai Pudong Int'l (PVG / ZSPD)
# 3    CCA837  A330     Beijing Capital Int'l (PEK / ZBAA)
# 4    CCA839  A332     Shanghai Pudong Int'l (PVG / ZSPD)
# 5    CCA841  A333     Beijing Capital Int'l (PEK / ZBAA)
# 6    CCA856  A330           London Heathrow (LHR / EGLL)
# 7    CCA862  A330     Geneva Cointrin Int'l (GVA / LSGG)
# 8    CCA875  A330     Beijing Capital Int'l (PEK / ZBAA)
# 9    CCA880  B773                Montreal-Trudeau (CYUL)
# 10   CCA890  A333  Chatrapati Shivaji Int'l (BOM / VABB)
# 11  CCA8903  B733   Dalian Zhoushuizi Int'l (DLC / ZYTL)
# 12  CCA8931  B733   Dalian Zhoushuizi Int'l (DLC / ZYTL)
# 13   CCA901  B738     Beijing Capital Int'l (PEK / ZBAA)
# 14   CCA904  B737        Tan Son Nhat Int'l (SGN / VVTS)
# 15   CCA907  B789     Beijing Capital Int'l (PEK / ZBAA)
# 16   CCA925  A333     Beijing Capital Int'l (PEK / ZBAA)
# 17   CCA932  B773           Frankfurt Int'l (FRA / EDDF)
# 18   CCA934  B773  Charles de Gaulle/Roissy (CDG / LFPG)
# 1        Sun 03:07PM CST
# 2       Sun 06:43AM CEST
# 3        Sat 05:12PM HST
# 4       Sun 08:08AM CEST
# 5       Sun 05:58AM CEST
# 6        Sun 03:29PM CST
# 7        Sun 12:34PM CST
# 8       Sun 07:12AM CEST
# 9        Sun 04:26PM CST
# 10       Sun 11:23AM CST
# 11       Sun 10:09AM CST
# 12       Sun 10:07AM CST
# 13       Sun 10:35AM +08
# 14       Sun 11:27AM CST
# 15      Sun 06:55AM CEST
# 16       Sun 01:48PM JST
# 17       Sun 11:27AM CST
# 18       Sun 12:18PM CST
# 19       Sun 12:48PM CST
#
# [200 rows x 6 columns]

# %%
import geocoder
g=geocoder.google('LaGuardia')
print(g.latlng)
# Out:
# [40.7769271, -73.8739659]

# %%
from functools import lru_cache

# %%
from cachier import cachier
import geocoder


@cachier()
def get_latlng(query):
    g=geocoder.google(query)
    if g:
        return g.latlng
    else:
        return None, None
    
great_lines = []
airports = []
airport_data = []
seen=[]
great_lines_2=[]
airports = pd.DataFrame(columns=['label','lat','lon'])
i=0
for index,row in df.iterrows():
    origin = row.Origin
    destination = row.Destination
    olat, olon = get_latlng(origin)
    dlat, dlon = get_latlng(destination)
    if olat and dlat:
    
        if origin not in seen:
            seen.append(origin)
            #print(origin, olat, olon)
        if destination not in seen:
            seen.append(destination)
            #print(destination, dlat, dlon)
        great_lines.append(dict(
        type = 'scattergeo',
        lat = [ olat, dlat ],
        lon = [ olon, dlon ],
        mode = 'lines',
        line = dict(
            width = 2,
            color = 'red',
            ),
            )
        )
        airports.loc[i]=[origin, olat, olon]
        airports.loc[i+1]= [destination, dlat, dlon]
        i+=2
airport_markers = [ dict(
        type = 'scattergeo',
        lon = airports['lon'],
        lat = airports['lat'],
        hoverinfo = 'label',
        text = airports['label'],
        mode = 'markers',
        marker = dict( 
            size=8, 
            color='red',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]
    
layout = dict(
        title = 'Great lines over globe<br>(Click and drag to rotate)',
        width = 800,
    height = 800,
        showlegend = False,         
        geo = dict(
            landcolor = '#f9f9f9',
            projection = dict( 
                type = 'orthographic',
                rotation = dict(
                    lon = 0,
                    lat = 0,
                    roll = 0
                )            
            ),
            lonaxis = dict( 
                showgrid = True,
                gridcolor = 'rgb(102, 102, 102)',
                gridwidth = 0.5
            ),
            lataxis = dict( 
                showgrid = True,
                gridcolor = 'rgb(102, 102, 102)',
                gridwidth = 0.5
            )
        )
    )
    
fig = dict( data=great_lines+airport_markers, layout=layout )
py.iplot( fig, validate=False, filename='d3-globe' )

# %%
url="http://flightaware.com/live/fleet/AAL?;offset=10000"
browser.open(url)
table=browser.select('.prettyTable')[0]
t=table.__str__()
if 'Sorry' in t:
    print('sorry')
df=pandas.read_html(t, header=1)[0]
# Out:
# sorry

# %%
df
# Out:
#                                                Ident  Type  Origin  \
# 0  Sorry. No matching flights found; try again la...   NaN     NaN
#
#    Destination  Departure  EstimatedArrival Time
# 0          NaN        NaN                    NaN
