# %%
from robobrowser import RoboBrowser
import geocoder
import folium
import pandas
import dateparser
from joblib import Memory
memory = Memory(cachedir='tmp', verbose=0)


@memory.cache
def get_latlng(query):
    g=geocoder.google(query)
    if g:
        print(query, g.latlng)
        return g.latlng
    else:
        return None, None
    
url = 'https://www.setlist.fm/search?page={}&query=Tool'
browser = RoboBrowser(history=True, parser='html5lib')
df = pandas.DataFrame(columns=['name', 'location', 'lat', 'lng', 'date'])
i=1


for page in range(1,10):
    browser.open(url.format(page))
    for concert in browser.select('.setlistPreview'):
        #<div class="condensed dateBlock">
        #<span class="month">Jul</span>
        #<span class="day">2</span>
        #<span class="year">2017</span>
        #</div>
        month = concert.select('.month')[0].text
        day = concert.select('.day')[0].text
        year = concert.select('.year')[0].text
        datetext = "{}, {} {}".format(year, month, day)
        date = dateparser.parse(datetext)
        desc = concert.select('h2 a')[0].text
        idx = desc.find(' at ')+4
        loc = desc[idx:]
        loc_pieces = loc.split(',')
        if loc == None:
            continue
        if len(loc_pieces)>=3:
            loc = ','.join(loc_pieces[-3:])
        lat, lng = get_latlng(loc)
        songs = concert.select('.list-inline li')
        for song in songs:
            songname = song.text
            if songname != '...':
                df.loc[i] = [songname, loc, lat, lng, date]
                i+=1
df=df.dropna()
df
# Out:
#  San Diego, CA, USA [32.715738, -117.1610838]
#  San Francisco, CA, USA [37.7749295, -122.4194155]
# Monster Mash 2015 [29.9736651, -95.5261752]
# Club Kamikaze, Mechelen, Belgium [51.024995, 4.4931233]
# Hedon, Zwolle, Netherlands [52.5170763, 6.0941918]
#  Phoenix, AZ, USA [33.4483771, -112.0740373]
#  Cedar Park, TX, USA [30.505198, -97.8202888]
# Cumbre Tajín 2014 [20.4567784, -97.31564519999999]
# Palacio de los Deportes, Mexico City, Mexico [19.4053359, -99.09986459999999]
#  Fresno, CA, USA [36.7468422, -119.7725868]
#  Portland, OR, USA [45.5230622, -122.6764815]
#  Spokane, WA, USA [47.6587802, -117.4260465]
# Balzaal Vooruit, Ghent, Belgium [51.0476851, 3.7274632]
# Colos-Saal, Aschaffenburg, Germany [49.9759284, 9.1490285]
# NAXT Stage, Almelo, Netherlands [52.3639044, 6.6498745]
# De Pul, Uden, Netherlands [51.663336, 5.6102485]
# Zentrum Altenberg, Oberhausen, Germany [51.475229, 6.847315]
#  North Hollywood, CA, USA [34.187044, -118.3812562]
# Vector Arena, Auckland, New Zealand [-36.8471841, 174.7768165]
#                          name                             location        lat  \
# 13   Message to Harry Manback                   Knoxville, TN, USA  35.960638
# 14        Hooker With a Penis                   Knoxville, TN, USA  35.960638
# 15                Intolerance                   Knoxville, TN, USA  35.960638
# 16                 The Grudge                   Knoxville, TN, USA  35.960638
# 17               Useful Idiot                   Knoxville, TN, USA  35.960638
# 18              Forty-Six & 2                   Knoxville, TN, USA  35.960638
# 19                     Mantra                   Knoxville, TN, USA  35.960638
# 20                     Schism                   Knoxville, TN, USA  35.960638
# 21                 Swamp Song                   Knoxville, TN, USA  35.960638
# 907                 Stinkfist  Vector Arena, Auckland, New Zealand -36.847184
#
#             lng       date
# 13   -83.920739 2017-07-29
# 14   -83.920739 2017-07-29
# 15   -83.920739 2017-07-29
# 16   -83.920739 2017-07-29
# 17   -83.920739 2017-07-29
# 18   -83.920739 2017-07-29
# 19   -83.920739 2017-07-29
# 20   -83.920739 2017-07-29
# 21   -83.920739 2017-07-29
# 22   -83.920739 2017-07-29
# 23   -83.920739 2017-07-29
# 24   -83.920739 2017-07-29
# 58  -121.886329 2017-06-21
# 59  -121.886329 2017-06-21
# 60  -121.886329 2017-06-21
# 61  -121.886329 2017-06-21
# 62  -121.886329 2017-06-21
# 63  -121.886329 2017-06-21
# 64  -121.886329 2017-06-21
# 65  -121.886329 2017-06-21
# 66  -121.886329 2017-06-21
# 67  -121.886329 2017-06-21
# 68  -121.886329 2017-06-21
# 69  -121.886329 2017-06-21
# 70  -116.563462 2017-06-18
# 71  -116.563462 2017-06-18
# 72  -116.563462 2017-06-18
# 73  -116.563462 2017-06-18
# 74  -116.563462 2017-06-18
# 75  -116.563462 2017-06-18
# ..          ...        ...
# 858    5.610248 2014-02-01
# 859    5.610248 2014-02-01
# 860    5.610248 2014-02-01
# 861    5.610248 2014-02-01
# 862    5.610248 2014-02-01
# 863    5.610248 2014-02-01
# 864    5.610248 2014-02-01
# 885  174.776816 2013-05-09
# 886  174.776816 2013-05-09
# 887  174.776816 2013-05-09
# 888  174.776816 2013-05-09
# 889  174.776816 2013-05-09
# 890  174.776816 2013-05-09
# 891  174.776816 2013-05-09
# 892  174.776816 2013-05-09
# 893  174.776816 2013-05-09
# 894  174.776816 2013-05-09
# 895  174.776816 2013-05-09
# 896  174.776816 2013-05-08
# 897  174.776816 2013-05-08
# 898  174.776816 2013-05-08
# 899  174.776816 2013-05-08
# 900  174.776816 2013-05-08
# 901  174.776816 2013-05-08
# 902  174.776816 2013-05-08
# 903  174.776816 2013-05-08
# 904  174.776816 2013-05-08
# 905  174.776816 2013-05-08
# 906  174.776816 2013-05-08
# 907  174.776816 2013-05-08
#
# [746 rows x 5 columns]

# %%
top_songs = df.name.value_counts().head(6)
colors = ['red','blue','yellow','green','orange','purple']
map = folium.Map(zoom_start=8, tiles='OpenStreetMap')
i=0
for song in top_songs.keys():
    i+=1
    color = colors.pop()
    dfc = df[df['name']==song]
    for index, row in dfc.iterrows():
        folium.Marker(
            location=[row.lat+i/5.0,row.lng+i/5.0],
            popup=u"%s - %s - %s" % (row['name'], row['location'], row['date']),
            icon=folium.Icon(color=color)
        ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
row
# Out:
# name                        Jambi
# location     San Antonio, TX, USA
# lat                       29.4241
# lng                      -98.4936
# date          2016-01-13 00:00:00
# Name: 536, dtype: object

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
top_songs.keys()
# Out:
# Index(['Bad Reputation', 'Do You Wanna Touch Me (Oh Yeah)', 'Cherry Bomb',
#        'Victim of Circumstance', 'Light of Day', 'Love Is Pain'],
#       dtype='object')

# %%
row['name']
# Out:
# 'Jambi'
